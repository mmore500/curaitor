# %%
from matplotlib import pyplot as plt
import seaborn as sns
from teeplot import teeplot as tp

# %%
from curaitor import example

# %%
# %load_ext watermark
# %watermark -iwbmuvg -iv
# Out:
# Last updated: 2025-02-16T00:34:43.102127+00:00
#
# Python implementation: CPython
# Python version       : 3.11.11
# IPython version      : 8.25.0
#
# Compiler    : GCC 13.2.0
# OS          : Linux
# Release     : 6.8.0-1021-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# Git hash: 055544da1e4f3b8de75ec53154fd12d54b7f782b
#
# Git branch: master
#
# teeplot   : 1.0.1
# seaborn   : 0.13.2
# matplotlib: 3.9.0
#
# Watermark: 2.4.3

# %%
tp.tee(
    sns.lineplot,
    x="timepoint",
    y="signal",
    hue="region",
    style="event",
    data=sns.load_dataset("fmri"),
    teeplot_outattrs={
        **{
            "custom": "attr",
        },
    },
)
plt.show()
# Out:
# teeplots/custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.pdf
# teeplots/custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.png
