# %%
from matplotlib import pyplot as plt
import seaborn as sns
from teeplot import teeplot as tp

# %%
from curaitor import example

# %%
# %load_ext watermark
# %watermark -iwbmuvg -iv
# Out:
# Last updated: 2024-06-28T10:04:26.943311+00:00
#
# Python implementation: CPython
# Python version       : 3.11.9
# IPython version      : 8.25.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.5.0-1022-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# Git hash: 3eab46363fbd4ee96843f263f06153529989f042
#
# Git branch: HEAD
#
# seaborn   : 0.13.2
# teeplot   : 1.0.1
# matplotlib: 3.9.0
#
# Watermark: 2.4.3

# %%
tp.tee(
    sns.lineplot,
    x="timepoint",
    y="signal",
    hue="region",
    style="event",
    data=sns.load_dataset("fmri"),
    teeplot_outattrs={
        **{
            "custom": "attr",
        },
    },
)
plt.show()
# Out:
# teeplots/custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.pdf
# teeplots/custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.png
